# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Используются данные академического рейтинга университетов мира.
# Ссылка на данные https://www.kaggle.com/mylesoneill/world-university-rankings?select=shanghaiData.csv.

# %%
shanghaiData = pd.read_csv('C:/Users/user/Downloads/shanghaiData.csv')
shanghaiData.head(20)
# Out:
#    world_rank                              university_name national_rank  \
# 0           1                           Harvard University             1
# 1           2                      University of Cambridge             1
# 2           3                          Stanford University             2
# 3           4           University of California, Berkeley             3
# 4           5  Massachusetts Institute of Technology (MIT)             4
# 5           6           California Institute of Technology             5
# 6           7                          Columbia University             6
# 7           8                         Princeton University             7
# 8           9                        University of Chicago             8
# 9          10                         University of Oxford             2
# 10         11                              Yale University             9
# 11         12                           Cornell University            10
# ...

# %% [markdown]
# Диаграмма рассеяния:

# %%
sns.pairplot(shanghaiData, hue = 'year')

# %%
sns.lineplot(x=shanghaiData.ns, y=shanghaiData.total_score)

# %% [markdown]
# Можно построить график violinplot, показывающий распределение `total_score` в каждом году.

# %%
sns.violinplot(x = 'year', y = 'total_score', data = shanghaiData)
